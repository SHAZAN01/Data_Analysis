# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAZAN01/Data_Analysis/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Data Frames-
#
# * Dataframes are two dimensional labelled data-structure.
# * Dataframes consist of rows and columns.
# * axis=0 means rows, axis=1 means columns

# %%
import pandas as pd
df = pd.DataFrame({'Names':['Tarun','Shaji','Rich','Pencil','Altaf'],
              'Scores': [50,60,20,30,60]
              })

# %%
df.shape
# Out:
# (5, 2)

# %%
df.columns
# Out:
# Index(['Names', 'Scores'], dtype='object')

# %%
# Alternative way of defining a dataframe
import pandas as pd
# List of rows(dictionaries) to make a dataframe
df = pd.DataFrame([{'Names':'stud1','Scores':11},
                  {'Names':'stud2','Scores':12},
                  {'Names':'stud3','Scores':13}])
# df.head()

# %% [markdown]
# DataFrames with series

# %%
import numpy as np
data1 = np.random.randint(1,10,5)
data2 = np.random.randint(1,10,5)

data1 = pd.Series(data1)
data2 = pd.Series(data1)

# df1 = pd.DataFrame(data1)
# df1

# df2 = pd.DataFrame(data2)
# df2

# %%
data = {'S1':data1, 'S2':data2}
data = pd.DataFrame(data)

# %%
# data.head()
data[:2]
# Out:
#    S1  S2
# 0   4   4
# 1   7   7

# %%
# data.tail()
# data.tail(2)
# data[::-1]
# data[3::-1]
data[4:2:-1]
# Out:
#    S1  S2
# 4   7   7
# 3   8   8

# %%
df = pd.DataFrame(np.random.randn(4,3),index=['a','b','c','d'],columns=['one','two','thre'])
df
# Out:
#         one       two      thre
# a  1.882485  0.210006 -1.421226
# b -0.863267  1.663765  1.646943
# c -0.268038 -1.824442 -0.289595
# d -1.483999 -0.730017  0.155678

# %%
df['four'] = 0

# %%
# df[df>0.2]
df['two'] [df['two']>0.2]
# df['two']>0.2
# Out:
# a    0.210006
# b    1.663765
# Name: two, dtype: float64

# %%
# df['b']
# create a column called five which is result of product first two columns
df['five'] = df['one']*df['two']
df
# Out:
#         one       two      thre  four      five
# a  1.882485  0.210006 -1.421226     0  0.395332
# b -0.863267  1.663765  1.646943     0 -1.436274
# c -0.268038 -1.824442 -0.289595     0  0.489019
# d -1.483999 -0.730017  0.155678     0  1.083345

# %%
df['six'] = np.random.randn(4,1)

# %%
df
# Out:
#         one       two      thre  four      five       six
# a  1.882485  0.210006 -1.421226     0  0.395332 -1.917954
# b -0.863267  1.663765  1.646943     0 -1.436274  0.387006
# c -0.268038 -1.824442 -0.289595     0  0.489019  1.005779
# d -1.483999 -0.730017  0.155678     0  1.083345  0.292526

# %% [markdown]
# ##loc, iloc

# %%
df = pd.DataFrame(np.random.randn(4,3),index=['a','b','c','d'],columns=['one','two','thre'])
df
# Out:
#         one       two      thre
# a -0.142379  2.701353  0.791300
# b -1.243062  0.704545  0.517661
# c  1.462877 -0.264419 -1.254914
# d -0.746237  1.066361  0.925401

# %%
# df.loc['a']
# df.loc['a','two']
df.loc['a']['two']
# Out:
# 2.7013525541452665

# %%
df.loc[['a','b']]
# Out:
#         one       two      thre
# a -0.142379  2.701353  0.791300
# b -1.243062  0.704545  0.517661

# %%
# df[['one','two']]
df.loc[:,['one','two']]
# Out:
#         one       two
# a -0.142379  2.701353
# b -1.243062  0.704545
# c  1.462877 -0.264419
# d -0.746237  1.066361

# %%
df
# Out:
#         one       two      thre
# a -0.142379  2.701353  0.791300
# b -1.243062  0.704545  0.517661
# c  1.462877 -0.264419 -1.254914
# d -0.746237  1.066361  0.925401

# %%
# df.loc['e'] = 2
# df

df.loc['f'] = 2
df
# Out:
#         one       two      thre
# a -0.142379  2.701353  0.791300
# b -1.243062  0.704545  0.517661
# c  1.462877 -0.264419 -1.254914
# d -0.746237  1.066361  0.925401
# f  2.000000  2.000000  2.000000

# %%
rows = [{'one':2.3,'two':3.3,'thre':4},
        {'one':1.3,'two':2.3,'thre':3.4},
        {'one':5.3,'two':3.3,'thre':4.4}]
df = df.append(rows,ignore_index=True)
# df.loc['g'] = rows
# df.index
df
# Out:
# <ipython-input-22-d9428c2a3716>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(rows,ignore_index=True)
#         one       two      thre
# 0 -0.142379  2.701353  0.791300
# 1 -1.243062  0.704545  0.517661
# 2  1.462877 -0.264419 -1.254914
# 3 -0.746237  1.066361  0.925401
# 4  2.000000  2.000000  2.000000
# 5  2.300000  3.300000  4.000000
# 6  1.300000  2.300000  3.400000
# 7  5.300000  3.300000  4.400000

# %%
# iloc
# df.iloc[]
df = df.reset_index(drop=True)
# df.iloc[0]
df.loc[0]
# Out:
# one    -0.142379
# two     2.701353
# thre    0.791300
# Name: 0, dtype: float64

# %%
df
# Out:
#         one       two      thre
# 0 -0.142379  2.701353  0.791300
# 1 -1.243062  0.704545  0.517661
# 2  1.462877 -0.264419 -1.254914
# 3 -0.746237  1.066361  0.925401
# 4  2.000000  2.000000  2.000000
# 5  2.300000  3.300000  4.000000
# 6  1.300000  2.300000  3.400000
# 7  5.300000  3.300000  4.400000

# %%
# df.iloc[:,::2]
df.loc[:,::2]
# Out:
#         one      thre
# 0 -0.142379  0.791300
# 1 -1.243062  0.517661
# 2  1.462877 -1.254914
# 3 -0.746237  0.925401
# 4  2.000000  2.000000
# 5  2.300000  4.000000
# 6  1.300000  3.400000
# 7  5.300000  4.400000

# %%
pd.DataFrame({('p', 'q'): {('P', 'Q'): 2, ('P', 'R'): 1},
               ('p', 'p'): {('P', 'R'): 4, ('P', 'Q'): 3},
               ('p', 'r'): {('P', 'Q'): 6, ('P', 'R'): 5},
               ('q', 'p'): {('P', 'R'): 8, ('P', 'Q'): 7},
               ('q', 'q'): {('P', 'S'): 10, ('P', 'Q'): 9}})
# Out:
#        p              q
#        q    p    r    p     q
# P Q  2.0  3.0  6.0  7.0   9.0
#   R  1.0  4.0  5.0  8.0   NaN
#   S  NaN  NaN  NaN  NaN  10.0

# %%
# https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv
df = pd.read_csv('https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# df = pd.read_csv('https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv',header=None)
# df
df = pd.read_csv('https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv',skiprows=1)
df
# Out:
#        -114.310000  34.190000  15.000000  5612.000000  1283.000000  \
# 0          -114.47      34.40       19.0       7650.0       1901.0
# 1          -114.56      33.69       17.0        720.0        174.0
# 2          -114.57      33.64       14.0       1501.0        337.0
# 3          -114.57      33.57       20.0       1454.0        326.0
# 4          -114.58      33.63       29.0       1387.0        236.0
# ...            ...        ...        ...          ...          ...
# 16994      -124.26      40.58       52.0       2217.0        394.0
# 16995      -124.27      40.69       36.0       2349.0        528.0
# 16996      -124.30      41.84       17.0       2677.0        531.0
# 16997      -124.30      41.80       19.0       2672.0        552.0
# 16998      -124.35      40.54       52.0       1820.0        300.0
#
#        1015.000000  472.000000  1.493600  66900.000000
# 0           1129.0       463.0    1.8200       80100.0
# ...

# %%
df = pd.read_csv('https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv',header=None,names=['long','lat','h_m_a','t_r','t_b','pop','hh','m_i','m_h_v'],skiprows=1)
df
# Out:
#          long    lat  h_m_a     t_r     t_b     pop     hh     m_i     m_h_v
# 0     -114.31  34.19   15.0  5612.0  1283.0  1015.0  472.0  1.4936   66900.0
# 1     -114.47  34.40   19.0  7650.0  1901.0  1129.0  463.0  1.8200   80100.0
# 2     -114.56  33.69   17.0   720.0   174.0   333.0  117.0  1.6509   85700.0
# 3     -114.57  33.64   14.0  1501.0   337.0   515.0  226.0  3.1917   73400.0
# 4     -114.57  33.57   20.0  1454.0   326.0   624.0  262.0  1.9250   65500.0
# ...       ...    ...    ...     ...     ...     ...    ...     ...       ...
# 16995 -124.26  40.58   52.0  2217.0   394.0   907.0  369.0  2.3571  111400.0
# 16996 -124.27  40.69   36.0  2349.0   528.0  1194.0  465.0  2.5179   79000.0
# 16997 -124.30  41.84   17.0  2677.0   531.0  1244.0  456.0  3.0313  103600.0
# 16998 -124.30  41.80   19.0  2672.0   552.0  1298.0  478.0  1.9797   85800.0
# 16999 -124.35  40.54   52.0  1820.0   300.0   806.0  270.0  3.0147   94600.0
#
# [17000 rows x 9 columns]

# %%
df.head(50)
# Out:
#       long    lat  h_m_a     t_r     t_b     pop      hh     m_i     m_h_v
# 0  -114.31  34.19   15.0  5612.0  1283.0  1015.0   472.0  1.4936   66900.0
# 1  -114.47  34.40   19.0  7650.0  1901.0  1129.0   463.0  1.8200   80100.0
# 2  -114.56  33.69   17.0   720.0   174.0   333.0   117.0  1.6509   85700.0
# 3  -114.57  33.64   14.0  1501.0   337.0   515.0   226.0  3.1917   73400.0
# 4  -114.57  33.57   20.0  1454.0   326.0   624.0   262.0  1.9250   65500.0
# 5  -114.58  33.63   29.0  1387.0   236.0   671.0   239.0  3.3438   74000.0
# 6  -114.58  33.61   25.0  2907.0   680.0  1841.0   633.0  2.6768   82400.0
# 7  -114.59  34.83   41.0   812.0   168.0   375.0   158.0  1.7083   48500.0
# 8  -114.59  33.61   34.0  4789.0  1175.0  3134.0  1056.0  2.1782   58400.0
# 9  -114.60  34.83   46.0  1497.0   309.0   787.0   271.0  2.1908   48100.0
# 10 -114.60  33.62   16.0  3741.0   801.0  2434.0   824.0  2.6797   86500.0
# ...

# %%
df.tail(50)
# Out:
#          long    lat  h_m_a     t_r     t_b     pop     hh     m_i     m_h_v
# 16950 -124.15  40.88   33.0  2235.0   506.0  1165.0  441.0  1.7250   57500.0
# 16951 -124.15  40.81   50.0   340.0    74.0   235.0   83.0  1.7500   67500.0
# 16952 -124.15  40.80   47.0  1486.0   335.0   765.0  329.0  1.7550   74100.0
# 16953 -124.15  40.79   37.0  2692.0   488.0  1263.0  486.0  3.0216   86400.0
# 16954 -124.15  40.78   36.0  2112.0   374.0   829.0  368.0  3.3984   90000.0
# 16955 -124.15  40.76   24.0  2858.0   511.0  1388.0  512.0  3.3750  100600.0
# 16956 -124.15  40.59   39.0  1186.0   238.0   539.0  212.0  2.0938   79600.0
# 16957 -124.16  41.74   15.0  2715.0   569.0  1532.0  530.0  2.1829   69500.0
# 16958 -124.16  41.02   23.0  1672.0   385.0  1060.0  390.0  2.1726   75500.0
# 16959 -124.16  40.95   20.0  1075.0   214.0   529.0  196.0  3.1406   96000.0
# 16960 -124.16  40.80   52.0  2416.0   618.0  1150.0  571.0  1.7308   80500.0
# ...

# %%
df.describe()
# Out:
#                long           lat         h_m_a           t_r           t_b  \
# count  17000.000000  17000.000000  17000.000000  17000.000000  17000.000000
# mean    -119.562108     35.625225     28.589353   2643.664412    539.410824
# std        2.005166      2.137340     12.586937   2179.947071    421.499452
# min     -124.350000     32.540000      1.000000      2.000000      1.000000
# 25%     -121.790000     33.930000     18.000000   1462.000000    297.000000
# 50%     -118.490000     34.250000     29.000000   2127.000000    434.000000
# 75%     -118.000000     37.720000     37.000000   3151.250000    648.250000
# max     -114.310000     41.950000     52.000000  37937.000000   6445.000000
#
#                 pop            hh           m_i          m_h_v
# count  17000.000000  17000.000000  17000.000000   17000.000000
# mean    1429.573941    501.221941      3.883578  207300.912353
# std     1147.852959    384.520841      1.908157  115983.764387
# ...

# %%
df.describe()['long']
# Out:
# count    17000.000000
# mean      -119.562108
# std          2.005166
# min       -124.350000
# 25%       -121.790000
# 50%       -118.490000
# 75%       -118.000000
# max       -114.310000
# Name: long, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   long    17000 non-null  float64
#  1   lat     17000 non-null  float64
#  2   h_m_a   17000 non-null  float64
#  3   t_r     17000 non-null  float64
#  4   t_b     17000 non-null  float64
#  5   pop     17000 non-null  float64
#  6   hh      17000 non-null  float64
#  7   m_i     17000 non-null  float64
#  8   m_h_v   17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df
# Out:
#          long    lat  h_m_a     t_r     t_b     pop     hh     m_i     m_h_v
# 0     -114.31  34.19   15.0  5612.0  1283.0  1015.0  472.0  1.4936   66900.0
# 1     -114.47  34.40   19.0  7650.0  1901.0  1129.0  463.0  1.8200   80100.0
# 2     -114.56  33.69   17.0   720.0   174.0   333.0  117.0  1.6509   85700.0
# 3     -114.57  33.64   14.0  1501.0   337.0   515.0  226.0  3.1917   73400.0
# 4     -114.57  33.57   20.0  1454.0   326.0   624.0  262.0  1.9250   65500.0
# ...       ...    ...    ...     ...     ...     ...    ...     ...       ...
# 16995 -124.26  40.58   52.0  2217.0   394.0   907.0  369.0  2.3571  111400.0
# 16996 -124.27  40.69   36.0  2349.0   528.0  1194.0  465.0  2.5179   79000.0
# 16997 -124.30  41.84   17.0  2677.0   531.0  1244.0  456.0  3.0313  103600.0
# 16998 -124.30  41.80   19.0  2672.0   552.0  1298.0  478.0  1.9797   85800.0
# 16999 -124.35  40.54   52.0  1820.0   300.0   806.0  270.0  3.0147   94600.0
#
# [17000 rows x 9 columns]

# %%
# df.mean()
df.median()
# Out:
# long       -118.4900
# lat          34.2500
# h_m_a        29.0000
# t_r        2127.0000
# t_b         434.0000
# pop        1167.0000
# hh          409.0000
# m_i           3.5446
# m_h_v    180400.0000
# dtype: float64

# %%
df.mode()
# Out:
#      long    lat  h_m_a     t_r    t_b    pop     hh    m_i     m_h_v
# 0 -118.31  34.06   52.0  1582.0  280.0  891.0  306.0  3.125  500001.0
# 1     NaN    NaN    NaN     NaN    NaN    NaN  386.0    NaN       NaN

# %%
df.min()
# Out:
# long      -124.3500
# lat         32.5400
# h_m_a        1.0000
# t_r          2.0000
# t_b          1.0000
# pop          3.0000
# hh           1.0000
# m_i          0.4999
# m_h_v    14999.0000
# dtype: float64

# %%
def half(a):
    return a/2

# %%
df = half(df)

# %%
df
# Out:
#          long     lat  h_m_a     t_r    t_b    pop     hh      m_i    m_h_v
# 0     -57.155  17.095    7.5  2806.0  641.5  507.5  236.0  0.74680  33450.0
# 1     -57.235  17.200    9.5  3825.0  950.5  564.5  231.5  0.91000  40050.0
# 2     -57.280  16.845    8.5   360.0   87.0  166.5   58.5  0.82545  42850.0
# 3     -57.285  16.820    7.0   750.5  168.5  257.5  113.0  1.59585  36700.0
# 4     -57.285  16.785   10.0   727.0  163.0  312.0  131.0  0.96250  32750.0
# ...       ...     ...    ...     ...    ...    ...    ...      ...      ...
# 16995 -62.130  20.290   26.0  1108.5  197.0  453.5  184.5  1.17855  55700.0
# 16996 -62.135  20.345   18.0  1174.5  264.0  597.0  232.5  1.25895  39500.0
# 16997 -62.150  20.920    8.5  1338.5  265.5  622.0  228.0  1.51565  51800.0
# 16998 -62.150  20.900    9.5  1336.0  276.0  649.0  239.0  0.98985  42900.0
# 16999 -62.175  20.270   26.0   910.0  150.0  403.0  135.0  1.50735  47300.0
#
# [17000 rows x 9 columns]

# %%
df = df.apply(half)

# %%
df
# Out:
#            long      lat  h_m_a      t_r      t_b      pop      hh       m_i  \
# 0     -14.28875  4.27375  1.875  701.500  160.375  126.875  59.000  0.186700
# 1     -14.30875  4.30000  2.375  956.250  237.625  141.125  57.875  0.227500
# 2     -14.32000  4.21125  2.125   90.000   21.750   41.625  14.625  0.206363
# 3     -14.32125  4.20500  1.750  187.625   42.125   64.375  28.250  0.398962
# 4     -14.32125  4.19625  2.500  181.750   40.750   78.000  32.750  0.240625
# ...         ...      ...    ...      ...      ...      ...     ...       ...
# 16995 -15.53250  5.07250  6.500  277.125   49.250  113.375  46.125  0.294637
# 16996 -15.53375  5.08625  4.500  293.625   66.000  149.250  58.125  0.314738
# 16997 -15.53750  5.23000  2.125  334.625   66.375  155.500  57.000  0.378912
# 16998 -15.53750  5.22500  2.375  334.000   69.000  162.250  59.750  0.247463
# 16999 -15.54375  5.06750  6.500  227.500   37.500  100.750  33.750  0.376837
#
#          m_h_v
# 0       8362.5
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=17000, step=1),
#  Index(['long', 'lat', 'h_m_a', 't_r', 't_b', 'pop', 'hh', 'm_i', 'm_h_v'], dtype='object')]

# %%
df['lat'].value_counts()
# Out:
# 4.25750    205
# 4.26000    200
# 4.25625    196
# 4.25875    194
# 4.25500    188
#           ...
# 4.99500      1
# 5.18750      1
# 4.92250      1
# 4.48875      1
# 5.23000      1
# Name: lat, Length: 840, dtype: int64

# %%
df.sort_values(by='long')
# Out:
#            long      lat  h_m_a      t_r      t_b      pop      hh       m_i  \
# 16999 -15.54375  5.06750  6.500  227.500   37.500  100.750  33.750  0.376837
# 16998 -15.53750  5.22500  2.375  334.000   69.000  162.250  59.750  0.247463
# 16997 -15.53750  5.23000  2.125  334.625   66.375  155.500  57.000  0.378912
# 16996 -15.53375  5.08625  4.500  293.625   66.000  149.250  58.125  0.314738
# 16995 -15.53250  5.07250  6.500  277.125   49.250  113.375  46.125  0.294637
# ...         ...      ...    ...      ...      ...      ...     ...       ...
# 4     -14.32125  4.19625  2.500  181.750   40.750   78.000  32.750  0.240625
# 3     -14.32125  4.20500  1.750  187.625   42.125   64.375  28.250  0.398962
# 2     -14.32000  4.21125  2.125   90.000   21.750   41.625  14.625  0.206363
# 1     -14.30875  4.30000  2.375  956.250  237.625  141.125  57.875  0.227500
# 0     -14.28875  4.27375  1.875  701.500  160.375  126.875  59.000  0.186700
#
#          m_h_v
# 16999  11825.0
# ...

# %% [markdown]
# example

# %%
import pandas as pd

# %%
data = {'Capitals': ['PANAJI', 'CHANDIGARH', 'PATNA', 'AGARTALA'],

      'Population': ['1,347,668', '21,144,564', '82,998,509','3,199,203'],

      'States': ['GOA', 'HARYANA', 'BIHAR', 'TRIPURA'],

      'Visitors': [300, 4000, 50, 80000],

      'area' : ["3,702", "44,212" ,"94,163", "10,486"]}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Capitals  Population   States  Visitors    area
# 0      PANAJI   1,347,668      GOA       300   3,702
# 1  CHANDIGARH  21,144,564  HARYANA      4000  44,212
# 2       PATNA  82,998,509    BIHAR        50  94,163
# 3    AGARTALA   3,199,203  TRIPURA     80000  10,486

# %%
df = df.set_index('States')
df
# Out:
#            Capitals  Population  Visitors    area
# States
# GOA          PANAJI   1,347,668       300   3,702
# HARYANA  CHANDIGARH  21,144,564      4000  44,212
# BIHAR         PATNA  82,998,509        50  94,163
# TRIPURA    AGARTALA   3,199,203     80000  10,486

# %%
# df.reset_index()

# %%
df.columns
# Out:
# Index(['Capitals', 'Population', 'Visitors', 'area'], dtype='object')

# %%
df.values
# Out:
# array([['PANAJI', '1,347,668', 300, '3,702'],
#        ['CHANDIGARH', '21,144,564', 4000, '44,212'],
#        ['PATNA', '82,998,509', 50, '94,163'],
#        ['AGARTALA', '3,199,203', 80000, '10,486']], dtype=object)

# %%
df1 = df.T
df1
# Out:
# States            GOA     HARYANA       BIHAR    TRIPURA
# Capitals       PANAJI  CHANDIGARH       PATNA   AGARTALA
# Population  1,347,668  21,144,564  82,998,509  3,199,203
# Visitors          300        4000          50      80000
# area            3,702      44,212      94,163     10,486

# %%
df['Visitors'].sum()
# Out:
# 84350

# %%
df1.loc['Visitors'].sum()
# Out:
# 84350

# %%
df1.BIHAR
# Out:
# Capitals           PATNA
# Population    82,998,509
# Visitors              50
# area              94,163
# Name: BIHAR, dtype: object

# %%
df
# Out:
#            Capitals  Population  Visitors    area
# States
# GOA          PANAJI   1,347,668       300   3,702
# HARYANA  CHANDIGARH  21,144,564      4000  44,212
# BIHAR         PATNA  82,998,509        50  94,163
# TRIPURA    AGARTALA   3,199,203     80000  10,486

# %%
df.loc['TELANGANA'] = ['HYDERABAD','100000',4000,'3,800']
df
# Out:
#              Capitals  Population  Visitors    area
# States
# GOA            PANAJI   1,347,668       300   3,702
# HARYANA    CHANDIGARH  21,144,564      4000  44,212
# BIHAR           PATNA  82,998,509        50  94,163
# TRIPURA      AGARTALA   3,199,203     80000  10,486
# TELANGANA   HYDERABAD      100000      4000   3,800

# %%
df.loc['TELANGANA','Population']  = '9,00,000'
# df.loc['TELANGANA'].Population = 900000
df
# Out:
#              Capitals  Population  Visitors    area
# States
# GOA            PANAJI   1,347,668       300   3,702
# HARYANA    CHANDIGARH  21,144,564      4000  44,212
# BIHAR           PATNA  82,998,509        50  94,163
# TRIPURA      AGARTALA   3,199,203     80000  10,486
# TELANGANA   HYDERABAD    9,00,000      4000   3,800

# %%
df['Population']['TELANGANA'] = '8,0,9,0'
df
# Out:
# <ipython-input-76-af18e39bf030>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population']['TELANGANA'] = '8,0,9,0'
#              Capitals  Population  Visitors    area
# States
# GOA            PANAJI   1,347,668       300   3,702
# HARYANA    CHANDIGARH  21,144,564      4000  44,212
# BIHAR           PATNA  82,998,509        50  94,163
# TRIPURA      AGARTALA   3,199,203     80000  10,486
# TELANGANA   HYDERABAD     8,0,9,0      4000   3,800

# %%
import numpy as np
# np.NaN
# df.loc['AP'] = ['AMARAVTHI',np.NaN,np.NaN,'3,800']
# Out:
# nan

# %%
# df.isna()
# df.isnull()
df.isna().sum()
# Out:
# Capitals      0
# Population    1
# Visitors      1
# area          0
# dtype: int64

# %%
df.notnull()
# Out:
#            Capitals  Population  Visitors  area
# States
# GOA            True        True      True  True
# HARYANA        True        True      True  True
# BIHAR          True        True      True  True
# TRIPURA        True        True      True  True
# TELANGANA      True        True      True  True
# AP             True       False     False  True

# %%
df.dropna()
# Out:
#              Capitals  Population  Visitors    area
# States
# GOA            PANAJI   1,347,668     300.0   3,702
# HARYANA    CHANDIGARH  21,144,564    4000.0  44,212
# BIHAR           PATNA  82,998,509      50.0  94,163
# TRIPURA      AGARTALA   3,199,203   80000.0  10,486
# TELANGANA   HYDERABAD     8,0,9,0    4000.0   3,800

# %%
# Example
a = pd.Series(['Tesla','tata',np.NaN,np.NaN,np.NaN,0,0,'audi'])

# %%
a
# Out:
# 0    Tesla
# 1     tata
# 2      NaN
# 3      NaN
# 4      NaN
# 5        0
# 6        0
# 7     audi
# dtype: object

# %%
# a.isnull()
# a.isna()
# a.isna().sum()
a[a.isna()]
# Out:
# 2    NaN
# 3    NaN
# 4    NaN
# dtype: object

# %%
a[a.notnull()]
# Out:
# 0    Tesla
# 1     tata
# 5        0
# 6        0
# 7     audi
# dtype: object

# %%
a.dropna(inplace = True)
a
# Out:
# 0    Tesla
# 1     tata
# 5        0
# 6        0
# 7     audi
# dtype: object

# %%
a.fillna(999)
# Out:
# 0    Tesla
# 1     tata
# 2      999
# 3      999
# 4      999
# 5        0
# 6        0
# 7     audi
# dtype: object

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
a.unique()
# Out:
# array(['Tesla', 'tata', nan, 0, 'audi'], dtype=object)
